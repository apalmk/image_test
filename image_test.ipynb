# %% [markdown]
# <a href="https://colab.research.google.com/github/apalmk/image_test/blob/master/image_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#load drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from google.colab.patches import cv2_imshow
import cv2

import numpy as np

# %% [markdown]
# #Locating the images with the associated number

# %%
image = cv2.imread('/content/gdrive/My Drive/test.tif', cv2.IMREAD_UNCHANGED);

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5,5))
gradient = cv2.morphologyEx(gray, cv2.MORPH_GRADIENT, kernel)

contours = cv2.findContours(gradient, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = imutils.grab_contours(contours)

for cnt in cnts:
    (x,y,w,h) = cv2.boundingRect(cnt)
    cv2.rectangle(image, (x,y), (x+w,y+h), (0,0,255))

# %%
cv2_imshow(gradient)
# Out:
# <PIL.Image.Image image mode=L size=1424x210 at 0x7F6737634630>

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1424x210 at 0x7F6737629F60>

# %% [markdown]
# #Locating only the images

# %%
image = cv2.imread('/content/gdrive/My Drive/test.tif')

hsv_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1424x210 at 0x7F67376290F0>

# %%
lt = np.array([1, 1, 1])

ut = np.array([255, 255, 255])

masking = cv2.inRange(hsv_img, lt,ut)

# %%
cv2_imshow(masking)
# Out:
# <PIL.Image.Image image mode=L size=1424x210 at 0x7F6737629F60>

# %%
contours = cv2.findContours(masking, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = imutils.grab_contours(contours)

for cnt in cnts:
    (x,y,w,h) = cv2.boundingRect(cnt)
    cv2.rectangle(image, (x,y), (x+w,y+h), (0,0,255))

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1424x210 at 0x7F6739806550>
